# %% [markdown]
# ### **Pregunta 2.**
#
# Realice lo mismo del inciso anterior con el uso de numpy y pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('/2023-03-08 Precios Casas RM.csv')
pd.set_option("display.max.columns", None)
df.head()
# Out:
#    Price_CLP  Price_UF  Price_USD             Comuna              Ubicacion  \
# 0  409285000     11500     509695       QuintaNormal        Hoevel4548y4558
# 1  105000000      2950     130760  PedroAguirreCerda               Rucalhue
# 2  128124000      3600     159557    EstaciónCentral     AvenidaLasParcelas
# 3   75000000      2107      93400             Colina     PasajeGonzaloRojas
# 4   53000000      1489      66002             Colina  HernánDíazArrieta2820
#
#    Dorms  Baths  Built Area  Total Area  Parking        id  \
# 0      7    4.0       384.0       732.0      3.0  11700213
# 1      2    1.0       112.0       145.0      1.0  10894299
# 2      3    1.0        59.0       243.0      2.0  10257635
# 3      3    1.0       103.0        73.0      1.0   9232092
# 4      2    1.0        57.0        67.0      1.0   7085397
#
#                         Realtor
# 0                           NaN
# 1     Legales y Propiedades SpA
# 2                 Propiedadesrs
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7779 entries, 0 to 7778
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Price_CLP   7779 non-null   int64
#  1   Price_UF    7779 non-null   int64
#  2   Price_USD   7779 non-null   int64
#  3   Comuna      7779 non-null   object
#  4   Ubicacion   7779 non-null   object
#  5   Dorms       7779 non-null   int64
#  6   Baths       7714 non-null   float64
#  7   Built Area  7533 non-null   float64
#  8   Total Area  7571 non-null   float64
#  9   Parking     5489 non-null   float64
#  10  id          7779 non-null   int64
#  11  Realtor     7184 non-null   object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 729.4+ KB

# %%
# Calcular la la media de precios en dolares
media = np.mean(df['Price_USD'])
print(f"Media del costo en dolares: {media:.2f}")
# Out:
# Media del costo en dolares: 453609.11

# %%
# Calcular percentiles
percentiles = [25, 50, 75]
percentile_values = np.percentile(df['Price_USD'], percentiles)
print(percentile_values)
# Out:
# [149440. 255293. 611634.]

# %%
posicion = 100
percentile_values = [df['Price_CLP'][posicion], df['Price_UF'][posicion], df['Price_USD'][posicion]]
percentiles = [25, 50, 75]
dato_resaltado = 255200


print (percentile_values)
# Crear el gráfico de percentiles
plt.figure(figsize=(8, 6))
plt.plot(percentiles, percentile_values, marker='o', linestyle='-', color='b', label='Percentiles')
plt.scatter([50], [dato_resaltado], color='r', marker='o', label='Dato Resaltado')  # Marcador para el dato resaltado
plt.xlabel('Percentiles')
plt.ylabel('Valores')
plt.title('Gráfico de Percentiles con Dato Resaltado')
plt.xticks(percentiles, [f'{p}%' for p in percentiles])  # Etiquetas en el eje x
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [188627000, 5300, 234903]

# %%
df.plot(x="Total Area", y=["Price_CLP", "Price_UF", "Price_USD"])
plt.show()

# %%
plt.plot(df["Total Area"], df["Price_CLP"])

# %%
df.plot(x="Total Area", y="Price_CLP")
# Out:
# <Axes: xlabel='Total Area'>

# %%
precio_dolares = df["Price_USD"]
type(precio_dolares)
# Out:
# pandas.core.series.Series

# %%
precio_dolares.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Nueva sección
